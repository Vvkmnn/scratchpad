# %%
Pkg.add("Gadfly")
Pkg.add("Cairo")
# Out:
# INFO: Nothing to be done
# INFO: METADATA is out-of-date — you may not have the latest version of Gadfly
# INFO: Use `Pkg.update()` to get the latest versions of your packages
# INFO: Cloning cache of Cairo from git://github.com/JuliaGraphics/Cairo.jl.git
# INFO: Cloning cache of Graphics from git://github.com/JuliaGraphics/Graphics.jl.git
# INFO: Installing Cairo v0.2.34
# INFO: Installing Graphics v0.1.3
# INFO: Building Homebrew
# ==> Homebrew has enabled anonymous aggregate user behaviour analytics
# Read the analytics documentation (and how to opt-out) here:
#   https://git.io/brew-analytics
# Updated Homebrew from 893c80d to aa165e1.
# Updated 1 tap (homebrew/core).
# ==> New Formulae
# direvent
# feedgnuplot
# fsevents-tools
# hg-fast-export
# hopenpgp-tools
# libdivecomputer
# pybind11
# vaulted
# ==> Updated Formulae
# afflib
# afl-fuzz
# amazon-ecs-cli
# android-ndk
# antigen
# app-engine-go-32
# app-engine-java
# app-engine-python
# apr-util
# arangodb
# argon2
# aria2
# aws-sdk-cpp
# awscli
# b2-tools
# bash-preexec
# brew-gem
# caddy
# charm
# convox
# coturn
# davix
# deis
# deisctl
# diff-pdf
# ditaa
# docker-machine
# emp
# etcd
# exploitdb
# fabio
# ffmpeg
# ffmpegthumbnailer
# fftw
# flatcc
# flow
# fontconfig
# fswatch
# fzf
# gawk
# gcc
# git-flow-avh
# git-fresh
# git-lfs
# giter8
# glide
# gnatsd
# grib-api
# gssh
# gst-editing-services
# gst-libav
# gst-plugins-bad
# gst-plugins-base
# gst-plugins-good
# gst-plugins-ugly
# gst-python
# gst-validate
# gstreamer
# gtk-vnc
# gx
# gx-go
# hadolint
# hbase
# highlight
# hyperscan
# infer
# jenkins
# jlog
# joe
# konoha
# kubernetes-cli
# kyua
# latexml
# leiningen
# libgit2-glib
# libgsf
# libphonenumber
# lmdb
# m-cli
# miller
# minio
# minio-mc
# mkvtoolnix
# mozjpeg
# mpc
# mpd
# mpich
# mpv
# mypy
# mysql-sandbox
# nanopb-generator
# nasm
# ncdu
# ncmpc
# nghttp2
# nomad
# nvm
# offlineimap
# open-mpi
# openvpn
# osh
# osm2pgsql
# osquery
# owfs
# parallel
# pcap_dnsproxy
# pdf2htmlex
# pdftoedn
# peco
# percona-server
# pmd
# poppler
# prometheus
# pwntools
# qbs
# rancher-cli
# rapidjson
# rclone
# re2
# repo
# rfcmarkup
# rocksdb
# sjk
# sngrep
# swiftlint
# syncthing
# tailor
# terraform
# tippecanoe
# tor
# vault
# vdirsyncer
# vim
# whatmp3
# yle-dl
# you-get
# youtube-dl
# ==> Renamed Formulae
# geode -> apache-geode
# ==> Deleted Formulae
# curaengine
# geany
# idcomments
# rfcdiff
# txt2man
# INFO: Building Cairo
# ==> Installing gettext from staticfloat/juliatranslated
# ==> Downloading https://homebrew.bintray.com/bottles/gettext-0.19.8.1.yosemite.bottle.tar.gz
# ==> Pouring gettext-0.19.8.1.yosemite.bottle.tar.gz
# ==> Caveats
# This formula is keg-only, which means it was not symlinked into /Users/vivek.menon/.julia/v0.4/Homebrew/deps/usr.
#
# OS X provides the BSD gettext library and some software gets confused if both are in the library path.
#
# Generally there are no consequences of this for you. If you build your
# own software and it requires this formula, you'll need to add to your
# build variables:
#
#     LDFLAGS:  -L/Users/vivek.menon/.julia/v0.4/Homebrew/deps/usr/opt/gettext/lib
#     CPPFLAGS: -I/Users/vivek.menon/.julia/v0.4/Homebrew/deps/usr/opt/gettext/include
#
# ==> Summary
# 🍺  /Users/vivek.menon/.julia/v0.4/Homebrew/deps/usr/Cellar/gettext/0.19.8.1: 1,934 files, 17.0M
# ==> Installing libpng from staticfloat/juliatranslated
# ==> Downloading https://homebrew.bintray.com/bottles/libpng-1.6.24.yosemite.bottle.tar.gz
# ==> Pouring libpng-1.6.24.yosemite.bottle.tar.gz
# 🍺  /Users/vivek.menon/.julia/v0.4/Homebrew/deps/usr/Cellar/libpng/1.6.24: 26 files, 1.2M
# Warning: Already linked: /Users/vivek.menon/.julia/v0.4/Homebrew/deps/usr/Cellar/libpng/1.6.24
# ==> Installing freetype from staticfloat/juliatranslated
# ==> Downloading https://homebrew.bintray.com/bottles/freetype-2.6.5.yosemite.bottle.tar.gz
# ==> Pouring freetype-2.6.5.yosemite.bottle.tar.gz
# 🍺  /Users/vivek.menon/.julia/v0.4/Homebrew/deps/usr/Cellar/freetype/2.6.5: 61 files, 2.5M
# Warning: Already linked: /Users/vivek.menon/.julia/v0.4/Homebrew/deps/usr/Cellar/freetype/2.6.5
# ==> Installing fontconfig from staticfloat/juliatranslated
# ==> Downloading https://homebrew.bintray.com/bottles/fontconfig-2.11.1_2.yosemite.bottle.tar.gz
# ==> Pouring fontconfig-2.11.1_2.yosemite.bottle.tar.gz
# ==> Regenerating font cache, this may take a while
# ==> /Users/vivek.menon/.julia/v0.4/Homebrew/deps/usr/Cellar/fontconfig/2.11.1_2/bin/fc-cache -frv
# 🍺  /Users/vivek.menon/.julia/v0.4/Homebrew/deps/usr/Cellar/fontconfig/2.11.1_2: 450 files, 2.9M
# Warning: Already linked: /Users/vivek.menon/.julia/v0.4/Homebrew/deps/usr/Cellar/fontconfig/2.11.1_2
# ==> Installing pixman from staticfloat/juliatranslated
# ==> Downloading https://homebrew.bintray.com/bottles/pixman-0.34.0.yosemite.bottle.tar.gz
# ==> Pouring pixman-0.34.0.yosemite.bottle.tar.gz
# 🍺  /Users/vivek.menon/.julia/v0.4/Homebrew/deps/usr/Cellar/pixman/0.34.0: 12 files, 1.2M
# Warning: Already linked: /Users/vivek.menon/.julia/v0.4/Homebrew/deps/usr/Cellar/pixman/0.34.0
# ==> Installing pcre from staticfloat/juliatranslated
# ==> Downloading https://homebrew.bintray.com/bottles/pcre-8.39.yosemite.bottle.tar.gz
# ==> Pouring pcre-8.39.yosemite.bottle.tar.gz
# 🍺  /Users/vivek.menon/.julia/v0.4/Homebrew/deps/usr/Cellar/pcre/8.39: 203 files, 5.4M
# Warning: Already linked: /Users/vivek.menon/.julia/v0.4/Homebrew/deps/usr/Cellar/pcre/8.39
# ==> Installing libffi from staticfloat/juliatranslated
# ==> Downloading https://homebrew.bintray.com/bottles/libffi-3.0.13.yosemite.bottle.tar.gz
# ==> Pouring libffi-3.0.13.yosemite.bottle.tar.gz
# ==> Caveats
# This formula is keg-only, which means it was not symlinked into /Users/vivek.menon/.julia/v0.4/Homebrew/deps/usr.
#
# Some formulae require a newer version of libffi.
#
# Generally there are no consequences of this for you. If you build your
# own software and it requires this formula, you'll need to add to your
# build variables:
#
#     LDFLAGS:  -L/Users/vivek.menon/.julia/v0.4/Homebrew/deps/usr/opt/libffi/lib
#
# ==> Summary
# 🍺  /Users/vivek.menon/.julia/v0.4/Homebrew/deps/usr/Cellar/libffi/3.0.13: 15 files, 377.2K
# ==> Installing glib from staticfloat/juliatranslated
# ==> Downloading https://homebrew.bintray.com/bottles/glib-2.48.1.yosemite.bottle.tar.gz
# ==> Pouring glib-2.48.1.yosemite.bottle.tar.gz
# 🍺  /Users/vivek.menon/.julia/v0.4/Homebrew/deps/usr/Cellar/glib/2.48.1: 425 files, 22.3M
# Warning: Already linked: /Users/vivek.menon/.julia/v0.4/Homebrew/deps/usr/Cellar/glib/2.48.1
# ==> Installing cairo from staticfloat/juliatranslated
# ==> Downloading https://homebrew.bintray.com/bottles/cairo-1.14.6_1.yosemite.bottle.tar.gz
# ==> Pouring cairo-1.14.6_1.yosemite.bottle.tar.gz
# 🍺  /Users/vivek.menon/.julia/v0.4/Homebrew/deps/usr/Cellar/cairo/1.14.6_1: 118 files, 5.9M
# Warning: Already linked: /Users/vivek.menon/.julia/v0.4/Homebrew/deps/usr/Cellar/cairo/1.14.6_1
# ==> Installing icu4c from staticfloat/juliatranslated
# ==> Downloading https://homebrew.bintray.com/bottles/icu4c-57.1.yosemite.bottle.tar.gz
# ==> Pouring icu4c-57.1.yosemite.bottle.tar.gz
# ==> Caveats
# This formula is keg-only, which means it was not symlinked into /Users/vivek.menon/.julia/v0.4/Homebrew/deps/usr.
#
# OS X provides libicucore.dylib (but nothing else).
#
# Generally there are no consequences of this for you. If you build your
# own software and it requires this formula, you'll need to add to your
# build variables:
#
#     LDFLAGS:  -L/Users/vivek.menon/.julia/v0.4/Homebrew/deps/usr/opt/icu4c/lib
#     CPPFLAGS: -I/Users/vivek.menon/.julia/v0.4/Homebrew/deps/usr/opt/icu4c/include
#
# ==> Summary
# 🍺  /Users/vivek.menon/.julia/v0.4/Homebrew/deps/usr/Cellar/icu4c/57.1: 265 files, 65M
# ==> Installing gobject-introspection from staticfloat/juliatranslated
# ==> Installing dependencies for staticfloat/juliatranslated/gobject-introspection: staticfloat/juliatranslated/pkg-config
# ==> Installing staticfloat/juliatranslated/gobject-introspection dependency: staticfloat/juliatranslated/pkg-config
# ==> Downloading https://homebrew.bintray.com/bottles/pkg-config-0.29.1_1.yosemite.bottle.tar.gz
# ==> Pouring pkg-config-0.29.1_1.yosemite.bottle.tar.gz
# 🍺  /Users/vivek.menon/.julia/v0.4/Homebrew/deps/usr/Cellar/pkg-config/0.29.1_1: 10 files, 627.5K
# ==> Installing staticfloat/juliatranslated/gobject-introspection
# ==> Downloading https://homebrew.bintray.com/bottles/gobject-introspection-1.48.0.yosemite.bottle.tar.gz
# ==> Pouring gobject-introspection-1.48.0.yosemite.bottle.tar.gz
# 🍺  /Users/vivek.menon/.julia/v0.4/Homebrew/deps/usr/Cellar/gobject-introspection/1.48.0: 170 files, 9.5M
# Warning: Already linked: /Users/vivek.menon/.julia/v0.4/Homebrew/deps/usr/Cellar/gobject-introspection/1.48.0
# ==> Installing harfbuzz from staticfloat/juliatranslated
# ==> Downloading https://homebrew.bintray.com/bottles/harfbuzz-1.3.0.yosemite.bottle.tar.gz
# ==> Pouring harfbuzz-1.3.0.yosemite.bottle.tar.gz
# 🍺  /Users/vivek.menon/.julia/v0.4/Homebrew/deps/usr/Cellar/harfbuzz/1.3.0: 123 files, 4.6M
# Warning: Already linked: /Users/vivek.menon/.julia/v0.4/Homebrew/deps/usr/Cellar/harfbuzz/1.3.0
# ==> Installing pango from staticfloat/juliatranslated
# ==> Downloading https://homebrew.bintray.com/bottles/pango-1.40.1.yosemite.bottle.tar.gz
# ==> Pouring pango-1.40.1.yosemite.bottle.tar.gz
# 🍺  /Users/vivek.menon/.julia/v0.4/Homebrew/deps/usr/Cellar/pango/1.40.1: 124 files, 5M
# Warning: Already linked: /Users/vivek.menon/.julia/v0.4/Homebrew/deps/usr/Cellar/pango/1.40.1
# INFO: Package database updated
# INFO: METADATA is out-of-date — you may not have the latest version of Cairo
# INFO: Use `Pkg.update()` to get the latest versions of your packages

# %%
using Gadfly
using Cairo
# Out:
# INFO: Precompiling module Gadfly...
# WARNING: New definition
#     +(AbstractArray{T<:Any, 2}, WoodburyMatrices.SymWoodbury) at /Users/vivek.menon/.julia/v0.4/WoodburyMatrices/src/SymWoodburyMatrices.jl:106
# is ambiguous with:
#     +(DataArrays.DataArray, AbstractArray) at /Users/vivek.menon/.julia/v0.4/DataArrays/src/operators.jl:276.
# To fix, define
#     +(DataArrays.DataArray{T<:Any, 2}, WoodburyMatrices.SymWoodbury)
# before the new definition.
# WARNING: New definition
#     +(AbstractArray{T<:Any, 2}, WoodburyMatrices.SymWoodbury) at /Users/vivek.menon/.julia/v0.4/WoodburyMatrices/src/SymWoodburyMatrices.jl:106
# is ambiguous with:
#     +(DataArrays.AbstractDataArray, AbstractArray) at /Users/vivek.menon/.julia/v0.4/DataArrays/src/operators.jl:300.
# To fix, define
#     +(DataArrays.AbstractDataArray{T<:Any, 2}, WoodburyMatrices.SymWoodbury)
# before the new definition.
# WARNING: New definition
#     +(AbstractArray{T<:Any, 2}, WoodburyMatrices.SymWoodbury) at /Users/vivek.menon/.julia/v0.4/WoodburyMatrices/src/SymWoodburyMatrices.jl:106
# is ambiguous with:
#     +(DataArrays.DataArray, AbstractArray) at /Users/vivek.menon/.julia/v0.4/DataArrays/src/operators.jl:276.
# To fix, define
#     +(DataArrays.DataArray{T<:Any, 2}, WoodburyMatrices.SymWoodbury)
# before the new definition.
# WARNING: New definition
#     +(AbstractArray{T<:Any, 2}, WoodburyMatrices.SymWoodbury) at /Users/vivek.menon/.julia/v0.4/WoodburyMatrices/src/SymWoodburyMatrices.jl:106
# is ambiguous with:
#     +(DataArrays.AbstractDataArray, AbstractArray) at /Users/vivek.menon/.julia/v0.4/DataArrays/src/operators.jl:300.
# To fix, define
#     +(DataArrays.AbstractDataArray{T<:Any, 2}, WoodburyMatrices.SymWoodbury)
# before the new definition.

# %%
plot(x=rand(10), y=rand(10))
# Out:
# Plot(...)

# %%
plot(x=rand(10), y=rand(10), Geom.point, Geom.line)
# Out:
# Plot(...)

# %%
plot(x=1:10, y=2.^rand(10),
     Scale.y_sqrt, Geom.point, Geom.smooth,
     Guide.xlabel("Stimulus"), Guide.ylabel("Response"), Guide.title("Dog Training"))
# Out:
# Plot(...)
